# %%
# library
library(dplyr)
library(reshape2)
library(ComplexHeatmap)
library(ggplot2)
library(cowplot)
library(gridGraphics)
library(grid)
library(circlize)

# %%
# ==== TCGA ====
# load color palette
source("color_palette.R")

load("../data/clustering_tcga_removing_badguys_mcpcounter.RData")

# %%
cell.types <- rownames(res.deconv.scale.tcga)
print(cell.types)
# Out:
#  [1] "T cell"                       "T cell CD8+"
#  [3] "NK cell"                      "B cell"
#  [5] "Monocyte"                     "Macrophage/Monocyte"
#  [7] "Myeloid dendritic cell"       "Neutrophil"
#  [9] "Endothelial cell"             "Cancer associated fibroblast"

# %%
cell.types.short <- c("T cell", "T cell CD8+", "NK cell", "B cell", "Monocyte", "Macrophage/Monocyte", "Myeloid", "Neutrophil", "Endothelial", "CAF")
rownames(res.deconv.scale.tcga) <- cell.types.short

# %%
p <- Heatmap(res.deconv.scale.tcga, column_title = NULL, show_heatmap_legend = FALSE,
             cluster_columns = FALSE, cluster_rows = FALSE,
             show_column_names = FALSE)
print(p)
# Out:
# The automatically generated colors map from the minus and plus 99^th of
# the absolute values in the matrix. There are outliers in the matrix
# whose patterns might be hidden by this color mapping. You can manually
# set the color to `col` argument.
#
# Use `suppressMessages()` to turn off this message.
# plot without title

# %%
p <- Heatmap(res.deconv.scale.tcga, column_title = "Cell type proportions across clusters on the TCGA dataset",
             show_heatmap_legend = TRUE, name = "Scaled\nproportion",
             column_split = res.deconv.sample.tcga$cluster,
             cluster_columns = FALSE, cluster_rows = FALSE,
             top_annotation = HeatmapAnnotation(foo = anno_block(gp = gpar(fill = color.three.clusters), labels = c("TCE", "EPCE", "TASCE"))),
             show_column_names = FALSE)
print(p)
# Out:
# The automatically generated colors map from the minus and plus 99^th of
# the absolute values in the matrix. There are outliers in the matrix
# whose patterns might be hidden by this color mapping. You can manually
# set the color to `col` argument.
#
# Use `suppressMessages()` to turn off this message.
# plot without title
