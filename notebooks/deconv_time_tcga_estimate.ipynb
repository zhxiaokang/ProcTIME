# %%
# deconvolute the TIME for TCGA dataset

library(tibble)
library(immunedeconv)
# Out:
# Loading required package: EPIC

# %%
load("../data/prad_data_tcga.RData")

# %%
# deconvolution
res.deconv <- deconvolute_estimate(as.matrix(prad.gene))
# Out:
# [1] "Merged dataset includes 10412 genes (0 mismatched)."
# [1] "1 gene set: StromalSignature  overlap= 141"
# [1] "2 gene set: ImmuneSignature  overlap= 141"

# %%
res.deconv
# Out:
#               TCGA.2A.A8VL  TCGA.2A.A8VO  TCGA.2A.A8VT  TCGA.2A.A8VV
# StromalScore  -1165.7033793  -752.8949132 -1086.3686297  -995.287928
# ImmuneScore   -1213.4658801  -924.0645011  -976.8178650 -1419.458137
# ESTIMATEScore -2379.1692594 -1676.9594143 -2063.1864947 -2414.746065
# TumorPurity       0.9674731     0.9363087     0.9547033     0.968781
#               TCGA.2A.A8VX  TCGA.2A.A8W1  TCGA.2A.A8W3  TCGA.2A.AAYF
# StromalScore  -1158.6383142 -1797.5482838  -819.6900611 -1057.0153404
# ImmuneScore   -1678.9483687 -1308.4950934 -1009.1083827 -1245.3902225
# ESTIMATEScore -2837.5866829 -3106.0433772 -1828.7984438 -2302.4055629
# TumorPurity       0.9822935     0.9889117     0.9439026     0.9645613
#               TCGA.2A.AAYO TCGA.2A.AAYU  ⋯ TCGA.ZG.A9LN TCGA.ZG.A9LS
# StromalScore  -290.7135872  -978.9844986 ⋯  116.5932235 435.619232
# ImmuneScore    168.2198244 -1364.6592038 ⋯ 1051.6204998 486.184975
# ESTIMATEScore -122.4937628 -2343.6437023 ⋯ 1168.2137233 921.804207
# TumorPurity      0.8326024     0.9661408 ⋯    0.7133935   0.738268
#               TCGA.ZG.A9LU  TCGA.ZG.A9LY  TCGA.ZG.A9LZ  TCGA.ZG.A9M4
# StromalScore   -950.4009773  -413.2152769  -653.4409766 -807.3865264
# ImmuneScore    -286.1905635  -587.6006017  -481.6567400  193.9875668
# ESTIMATEScore -1236.5915408 -1000.8158786 -1135.0977165 -613.3989596
# TumorPurity       0.9116686     0.8969037     0.9054456    0.8703187
#               TCGA.ZG.A9MC TCGA.ZG.A9N3  TCGA.ZG.A9ND  TCGA.ZG.A9NI
# StromalScore   167.6113337 -1255.7090901 -1252.2524768   42.8614961
# ImmuneScore   1174.0300116  -198.7303500 -1125.7123987 -843.4714988
# ESTIMATEScore 1341.6413454 -1454.4394401 -2377.9648755 -800.6100028
# TumorPurity      0.6953248     0.9243407     0.9674284    0.8835222
